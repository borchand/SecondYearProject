# %%
# !python3 eval.py --batch_size 32
# !python3 eval.py --discriminative_lr True --batch_size 32
# !python3 eval.py --cosine_schedule True --batch_size 32
# !python3 eval.py --discriminative_lr True --cosine_schedule True --batch_size 32

# %%
import pandas as pd

# %%
pd.read_csv("./evaluations/baseline.csv")
# Out:
#      Dataset   Language  eval_loss  eval_precision  eval_recall   eval_f1  \
# 0   Baseline    English   0.268799        0.656716     0.575163  0.613240
# 1    NoSta-D     German   0.374505        0.537153     0.462294  0.496920
# 2    DaNplus     Danish   0.340588        0.319908     0.288382  0.303328
# 3  Hungarian  Hungarian   0.696006        0.084341     0.109656  0.095347
#
#    eval_span_f1  eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0      0.645465       0.919411       24.1695                   11.792
# 1      0.536514       0.918233      476.5472                   10.702
# 2      0.320661       0.919177       74.4392                    7.604
# 3      0.114086       0.867018      257.6673                    3.594
#
#    eval_steps_per_second
# 0                  0.372
# 1                  0.336
# 2                  0.242
# 3                  0.113

# %%
pd.read_csv("./evaluations/scheduler.csv")
# Out:
#      Dataset   Language  eval_loss  eval_precision  eval_recall   eval_f1  \
# 0   Baseline    English   0.269856        0.678873     0.525054  0.592138
# 1    NoSta-D     German   0.315366        0.587804     0.440046  0.503305
# 2    DaNplus     Danish   0.279915        0.443096     0.302905  0.359827
# 3  Hungarian  Hungarian   0.492525        0.113941     0.095434  0.103870
#
#    eval_span_f1  eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0      0.626866       0.917570       23.4007                   12.179
# 1      0.551747       0.921940      482.6008                   10.568
# 2      0.392745       0.929491       78.1617                    7.241
# 3      0.127447       0.886173      263.8905                    3.509
#
#    eval_steps_per_second
# 0                  0.385
# 1                  0.332
# 2                  0.230
# 3                  0.110

# %%
pd.read_csv("./evaluations/discriminative-lr.csv")
# Out:
#      Dataset   Language  eval_loss  eval_precision  eval_recall   eval_f1  \
# 0   Baseline    English   0.288196        0.629291     0.599129  0.613839
# 1    NoSta-D     German   0.363792        0.568852     0.488972  0.525896
# 2    DaNplus     Danish   0.323306        0.334995     0.348548  0.341637
# 3  Hungarian  Hungarian   0.656631        0.080340     0.141467  0.102481
#
#    eval_span_f1  eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0      0.650794       0.917775       23.1586                   12.306
# 1      0.563886       0.922011      454.2502                   11.227
# 2      0.373774       0.923081       78.0874                    7.248
# 3      0.114420       0.854914     6235.9918                    0.148
#
#    eval_steps_per_second
# 0                  0.389
# 1                  0.352
# 2                  0.231
# 3                  0.005

# %%
pd.read_csv("./evaluations/scheduler-AND-discriminative-lr.csv")
# Out:
#      Dataset   Language  eval_loss  eval_precision  eval_recall   eval_f1  \
# 0   Baseline    English   0.287295        0.649083     0.616558  0.632402
# 1    NoSta-D     German   0.361604        0.555368     0.507657  0.530442
# 2    DaNplus     Danish   0.292022        0.389485     0.376556  0.382911
# 3  Hungarian  Hungarian   0.523018        0.150922     0.202096  0.172800
#
#    eval_span_f1  eval_accuracy  eval_runtime  eval_samples_per_second  \
# 0      0.675958       0.922684       28.9877                    9.832
# 1      0.574145       0.921594      471.7344                   10.811
# 2      0.427015       0.927277       69.8750                    8.100
# 3      0.200272       0.872255      238.3136                    3.886
#
#    eval_steps_per_second
# 0                  0.310
# 1                  0.339
# 2                  0.258
# 3                  0.122
